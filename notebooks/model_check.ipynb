# %%
import sys
sys.path.append('..')

# %%
import torch
from src.models import UNet
from torchsummary import summary

# %%
model = UNet(n_channels=3, n_classes=1, bilinear=True)
print(model)
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
from src.viz_utils import print_model_summary
print_model_summary(model)
# Out:
# __________________________________________________________________________________________________________________________________
# Layer                                                       Size                                    Parameters           Trainable
# __________________________________________________________________________________________________________________________________
# inc.double_conv.0.weight                                    torch.Size([64, 3, 3, 3])                     1728                True
# ----------------------------------------------------------------------------------------------------------------------------------
# inc.double_conv.0.bias                                      torch.Size([64])                                64                True
# ----------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
#do forward pass and check logits
with torch.no_grad():
    logits = model(torch.randn(4, 3, 512, 512))
print(logits.shape)
# Out:
# torch.Size([4, 1, 512, 512])

# %%
summary(model, input_size=(3, 512, 512), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 512, 512]           1,792
#        BatchNorm2d-2         [-1, 64, 512, 512]             128
#               ReLU-3         [-1, 64, 512, 512]               0
#             Conv2d-4         [-1, 64, 512, 512]          36,928
#        BatchNorm2d-5         [-1, 64, 512, 512]             128
#               ReLU-6         [-1, 64, 512, 512]               0
#         DoubleConv-7         [-1, 64, 512, 512]               0
#          MaxPool2d-8         [-1, 64, 256, 256]               0
#             Conv2d-9        [-1, 128, 256, 256]          73,856
#       BatchNorm2d-10        [-1, 128, 256, 256]             256
#              ReLU-11        [-1, 128, 256, 256]               0
#            Conv2d-12        [-1, 128, 256, 256]         147,584
#       BatchNorm2d-13        [-1, 128, 256, 256]             256
# ...
